# %% [markdown]
# ## Import Libraries

# %%
import os                               # For interacting with the operating system
from PIL import Image, UnidentifiedImageError  # To work with images and handle image-related errors
import numpy as np                      # For numerical computations and array manipulation
from sklearn.model_selection import cross_val_predict  # To perform cross-validation and generate predictions
from sklearn.preprocessing import LabelEncoder         # To encode labels into integers
from xgboost import XGBClassifier       # Import the XGBoost classifier for machine learning tasks
import cleanlab                         # For handling noisy labels in datasets
import random                           # To generate random numbers or shuffle data

# %% [markdown]
# ## Image filltering

# %%
class InvalidImageSizeError(Exception):
    """Custom exception raised when an image does not meet the required size."""
    pass

# Path of all image files
base_path = r'C:\\Users\\cbado\\OneDrive - University of Huddersfield\\Year 3\\Data Driven AI\\Assignment 2\\hand images'

# Dictionaries to track the number of errors for each stage
unable_to_open_count = {f"Stage{i}": 0 for i in range(1, 9)}  # Count for images that couldn't be opened
invalid_size_count = {f"Stage{i}": 0 for i in range(1, 9)}  # Count for images that don't match the expected size
invalid_extension_count = {f"Stage{i}": 0 for i in range(1, 9)}  # Count for images with unsupported file extensions

train_data = []  # A list to hold the image data (model input)
image_paths = []  # A list to hold the paths to the images
labels = []  # A list to store the labels


# Traverse through each Stage folder and process images
for folder in os.listdir(base_path):
    folder_path = os.path.join(base_path, folder)  # Construct the full path to the current stage folder
    stage_key = folder  # Use the folder name as a unique identifier for counting issues in this stage
    for file in os.listdir(folder_path):  # Loop through all files in the current stage folder
        # Check if the file has a valid image extension
        if file.endswith((".png", ".jpg", ".jpeg", ".PNG", ".JPG", ".JPEG",)):
            img_path = os.path.join(folder_path, file)  # Get the full path of the image file

            try:
                img = Image.open(img_path).convert("L")  # Open the image and convert it to grayscale
                # Check if the image is the required size of 150x150 pixels
                if img.size != (150, 150):
                    raise InvalidImageSizeError()  # Raise an error if the image size is not 150x150
                
                # Flatten the image and append it to the training data list
                train_data.append(np.array(img).flatten())
                image_paths.append(img_path)  # store the image path
                labels.append(folder)  # Store the folder name as the label
                
            except (InvalidImageSizeError, UnidentifiedImageError, OSError) as e:
                # Handle the errors during image processing
                if isinstance(e, InvalidImageSizeError):
                    print(f"Image size of {file} is {img.size}, but it must be 150x150.\n")
                    invalid_size_count[stage_key] += 1  # Increment the count for invalid size in the current stage
                elif isinstance(e, UnidentifiedImageError):
                    unable_to_open_count[stage_key] += 1  # Increment the count for images that couldn't be opened
                    print(f"Unable to open Image: {file}\n")  # Print the error message for failed image opening
                else:
                    pass  # If there is another error, simply skip without incrementing counts
                    print(f"Error processing image {file}: {e}\n")
        else:
            invalid_extension_count[stage_key] += 1  # Increment the count for images with invalid extensions
            print(f"{file} has invalid extension\n")  # Print the filename with an unsupported extension
# Out:
# Image size of 10_Stage_1_U2254663.jpg is (290, 236), but it must be 150x150.
#
# 1_10_2162526.HEIC has invalid extension
#
# Image size of 1_10_2254417.jpg is (177, 177), but it must be 150x150.
#
# 1_1_2162526.HEIC has invalid extension
#
# Image size of 1_1_2254417.jpg is (177, 177), but it must be 150x150.
#
# 1_2_2162526.HEIC has invalid extension
#
# Image size of 1_2_2254417.jpg is (177, 177), but it must be 150x150.
#
# 1_3_2162526.HEIC has invalid extension
#
# Image size of 1_3_2254417.jpg is (177, 177), but it must be 150x150.
#
# 1_4_2162526.HEIC has invalid extension
#
# Image size of 1_4_2254417.jpg is (177, 177), but it must be 150x150.
#
# 1_5_2162526.HEIC has invalid extension
#
# Image size of 1_5_2254417.jpg is (177, 177), but it must be 150x150.
#
# 1_6_2162526.HEIC has invalid extension
#
# Image size of 1_6_2254417.jpg is (177, 177), but it must be 150x150.
#
# 1_7_2162526.HEIC has invalid extension
#
# Image size of 1_7_2254417.jpg is (177, 177), but it must be 150x150.
#
# 1_8_2162526.HEIC has invalid extension
#
# Image size of 1_8_2254417.jpg is (177, 177), but it must be 150x150.
#
# 1_9_2162526.HEIC has invalid extension
#
# Image size of 1_9_2254417.jpg is (177, 177), but it must be 150x150.
#
# Image size of 1_Stage_1_U2254663.jpg is (268, 221), but it must be 150x150.
#
# Unable to open Image: 20241116_035521674_iOS 1.jpg
#
# Image size of 20241116_035521674_iOS.jpg is (119, 160), but it must be 150x150.
#
# Image size of 20241116_035602785_iOS 1.jpg is (119, 160), but it must be 150x150.
#
# Image size of 20241116_035602785_iOS.jpg is (119, 160), but it must be 150x150.
#
# Image size of 20241116_035651681_iOS 1.jpg is (119, 160), but it must be 150x150.
#
# Image size of 20241116_035651681_iOS.jpg is (119, 160), but it must be 150x150.
#
# Image size of 20241116_035726513_iOS 1.jpg is (119, 160), but it must be 150x150.
#
# Image size of 20241116_035726513_iOS.jpg is (119, 160), but it must be 150x150.
#
# Image size of 20241116_035757655_iOS 1.jpg is (119, 160), but it must be 150x150.
#
# Image size of 20241116_035757655_iOS.jpg is (119, 160), but it must be 150x150.
#
# Unable to open Image: 20241116_035840182_iOS 1.jpg
#
# Image size of 20241116_035840182_iOS 2.jpg is (119, 160), but it must be 150x150.
#
# Image size of 20241116_035840182_iOS.jpg is (119, 160), but it must be 150x150.
#
# Image size of 20241116_040005270_iOS 1.jpg is (119, 160), but it must be 150x150.
#
# Image size of 20241116_040005270_iOS.jpg is (119, 160), but it must be 150x150.
#
# Image size of 20241116_040053948_iOS 1.jpg is (119, 160), but it must be 150x150.
#
# Image size of 20241116_040053948_iOS.jpg is (119, 160), but it must be 150x150.
#
# Image size of 20241116_040133191_iOS 1.jpg is (119, 160), but it must be 150x150.
#
# Image size of 20241116_040133191_iOS.jpg is (119, 160), but it must be 150x150.
#
# Image size of 20241116_040215195_iOS.jpg is (119, 160), but it must be 150x150.
#
# Image size of 2_Stage_1_U2254663.jpg is (290, 236), but it must be 150x150.
#
# Image size of 3_Stage_1_U2254663.jpg is (297, 254), but it must be 150x150.
#
# Image size of 4_Stage_1_U2254663.jpg is (244, 278), but it must be 150x150.
#
# Image size of 5_Stage_1_U2254663.jpg is (272, 289), but it must be 150x150.
#
# Image size of 6_Stage_1_U2254663.jpg is (213, 219), but it must be 150x150.
#
# Image size of 7_Stage_1_U2254663.jpg is (273, 268), but it must be 150x150.
#
# Image size of 8_Stage_1_U2254663.jpg is (246, 207), but it must be 150x150.
#
# Image size of 9_Stage_1_U2254663.jpg is (229, 252), but it must be 150x150.
#
# Image size of Resized S 1-U2187423-1.jpg is (113, 150), but it must be 150x150.
#
# Image size of Resized S 1-U2187423-10.jpg is (113, 150), but it must be 150x150.
#
# Image size of Resized S 1-U2187423-2.jpg is (113, 150), but it must be 150x150.
#
# Image size of Resized S 1-U2187423-3.jpg is (113, 150), but it must be 150x150.
#
# Image size of Resized S 1-U2187423-4.jpg is (113, 150), but it must be 150x150.
#
# Image size of Resized S 1-U2187423-5.jpg is (113, 150), but it must be 150x150.
#
# Image size of Resized S 1-U2187423-6.jpg is (113, 150), but it must be 150x150.
#
# Image size of Resized S 1-U2187423-7.jpg is (113, 150), but it must be 150x150.
#
# Image size of Resized S 1-U2187423-8.jpg is (113, 150), but it must be 150x150.
#
# Image size of Resized S 1-U2187423-9.jpg is (113, 150), but it must be 150x150.
#
# Image size of Sagte_1_2452781(10).jpg is (1478, 1276), but it must be 150x150.
#
# Image size of stage 1 (u2187406).jpg is (3840, 5120), but it must be 150x150.
#
# Image size of STAGE 1 ANGLE 1 U2266514.jpg is (3024, 4032), but it must be 150x150.
#
# Image size of STAGE 1 ANGLE 1.jpg is (3024, 4032), but it must be 150x150.
#
# Image size of Stage 1 Angle 10 U2266514.jpg is (4032, 3024), but it must be 150x150.
#
# Image size of STAGE 1 ANGLE 10.jpg is (4032, 3024), but it must be 150x150.
#
# Image size of STAGE 1 ANGLE 5 U2266514.jpg is (3024, 4032), but it must be 150x150.
#
# Image size of STAGE 1 ANGLE 5.jpg is (3024, 4032), but it must be 150x150.
#
# Image size of STAGE 1 ANGLE 6.jpg is (3024, 4032), but it must be 150x150.
#
# Image size of STAGE 1 ANGLE 7.jpg is (3024, 4032), but it must be 150x150.
#
# Image size of Stage 1 Angle 9 U2266514.jpg is (3024, 4032), but it must be 150x150.
#
# Image size of Stage 1 Angle 9.jpg is (3024, 4032), but it must be 150x150.
#
# Image size of STAGE 1 ANGLE2 U2266514 .jpg is (3024, 4032), but it must be 150x150.
#
# Image size of STAGE 1 ANGLE2.jpg is (3024, 4032), but it must be 150x150.
#
# Image size of STAGE 1 ANGLE3 U2266514.jpg is (3024, 4032), but it must be 150x150.
#
# Image size of STAGE 1 ANGLE3.jpg is (3024, 4032), but it must be 150x150.
#
# Image size of STAGE 1 ANGLE8 U2266514.jpg is (3024, 4032), but it must be 150x150.
#
# Image size of STAGE 1 ANGLE8.jpg is (3024, 4032), but it must be 150x150.
#
# Image size of stage 1 u2187422.jpg (2).jpg is (150, 200), but it must be 150x150.
#
# Image size of STAGE 1 u2187422.jpg.jpg is (150, 200), but it must be 150x150.
#
# Image size of Stage 1-2187423-1.jpg is (113, 150), but it must be 150x150.
#
# Image size of Stage 1-2187423-10.jpg is (113, 150), but it must be 150x150.
#
# Image size of Stage 1-2187423-2.jpg is (113, 150), but it must be 150x150.
#
# Image size of Stage 1-2187423-3.jpg is (113, 150), but it must be 150x150.
#
# Image size of Stage 1-2187423-4.jpg is (113, 150), but it must be 150x150.
#
# Image size of Stage 1-2187423-5.jpg is (113, 150), but it must be 150x150.
#
# Image size of Stage 1-2187423-6.jpg is (113, 150), but it must be 150x150.
#
# Image size of Stage 1-2187423-7.jpg is (113, 150), but it must be 150x150.
#
# Image size of Stage 1-2187423-8.jpg is (113, 150), but it must be 150x150.
#
# Image size of Stage 1-2187423-9.jpg is (113, 150), but it must be 150x150.
#
# Image size of STAGE1 ANGEL 4 U2266514.jpg is (3024, 4032), but it must be 150x150.
#
# Image size of STAGE1 ANGEL 4.jpg is (3024, 4032), but it must be 150x150.
#
# Image size of Stage1 u218722.jpg.jpg is (150, 200), but it must be 150x150.
#
# Image size of stage1 U2187422.jpg (2).jpg is (150, 200), but it must be 150x150.
#
# Image size of Stage1 U2187422.jpg (3).jpg is (150, 200), but it must be 150x150.
#
# Image size of stage1 u2187422.jpg (4).jpg is (150, 200), but it must be 150x150.
#
# Image size of stage1 u2187422.jpg.jpg is (150, 200), but it must be 150x150.
#
# Image size of Stage1 u2187422;jpg.jpg is (150, 200), but it must be 150x150.
#
# Image size of stage1. U2187422.JPG.jpg is (150, 200), but it must be 150x150.
#
# Image size of stage1.U2187422.jpg.jpg is (150, 200), but it must be 150x150.
#
# Unable to open Image: stage1_u2353673(1)copy.jpg
#
# Unable to open Image: stage1_u2353673(10) copy.jpg
#
# Unable to open Image: stage1_u2353673(2) copy.jpg
#
# Unable to open Image: stage1_u2353673(3) copy.jpg
#
# Unable to open Image: stage1_u2353673(4) copy.jpg
#
# Unable to open Image: stage1_u2353673(5) copy.jpg
#
# Unable to open Image: stage1_u2353673(6) copy.jpg
#
# Unable to open Image: stage1_u2353673(7) copy.jpg
#
# Unable to open Image: stage1_u2353673(8) copy.jpg
#
# Unable to open Image: stage1_u2353673(9) copy.jpg
#
# Image size of Stage_1.10_u2352832.jpg is (3072, 3072), but it must be 150x150.
#
# Image size of Stage_1.1_u2352832.jpg is (3072, 3071), but it must be 150x150.
#
# Image size of Stage_1.2_u2352832.jpg is (3072, 3072), but it must be 150x150.
#
# Image size of Stage_1.3_u2352832.jpg is (3072, 3072), but it must be 150x150.
#
# Image size of Stage_1.4_u2352832.jpg is (3072, 3072), but it must be 150x150.
#
# Image size of Stage_1.5_u2352832.jpg is (3072, 3072), but it must be 150x150.
#
# Image size of Stage_1.6_u2352832.jpg is (3072, 3072), but it must be 150x150.
#
# Image size of Stage_1.7_u2352832.jpg is (3072, 3072), but it must be 150x150.
#
# Image size of Stage_1.8_u2352832.jpg is (3072, 3072), but it must be 150x150.
#
# Image size of Stage_1.9_u2352832.jpg is (3072, 3072), but it must be 150x150.
#
# Image size of Stage_1_2452781(1).jpg is (1282, 1338), but it must be 150x150.
#
# Image size of Stage_1_2452781(2).jpg is (1420, 1282), but it must be 150x150.
#
# Image size of Stage_1_2452781(3).jpg is (1328, 1282), but it must be 150x150.
#
# Image size of Stage_1_2452781(4).jpg is (1368, 1280), but it must be 150x150.
#
# Image size of Stage_1_2452781(5).jpg is (1482, 1284), but it must be 150x150.
#
# Image size of Stage_1_2452781(6).jpg is (1290, 1284), but it must be 150x150.
#
# Image size of Stage_1_2452781(7).jpg is (1292, 1278), but it must be 150x150.
#
# Image size of Stage_1_2452781(8).jpg is (1352, 1278), but it must be 150x150.
#
# Image size of Stage_1_2452781(9).jpg is (1490, 1278), but it must be 150x150.
#
# Image size of Stage_1_U2161141_1.jpg is (4252, 4252), but it must be 150x150.
#
# Image size of Stage_1_U2161141_10.jpg is (4252, 4252), but it must be 150x150.
#
# Image size of Stage_1_U2161141_2.jpg is (4252, 4252), but it must be 150x150.
#
# Image size of Stage_1_U2161141_3.jpg is (4252, 4252), but it must be 150x150.
#
# Image size of Stage_1_U2161141_4.jpg is (4252, 4252), but it must be 150x150.
#
# Image size of Stage_1_U2161141_5.jpg is (4252, 4252), but it must be 150x150.
#
# Image size of Stage_1_U2161141_6.jpg is (4252, 4252), but it must be 150x150.
#
# Image size of Stage_1_U2161141_7.jpg is (4252, 4252), but it must be 150x150.
#
# Image size of Stage_1_U2161141_8.jpg is (4252, 4252), but it must be 150x150.
#
# Image size of Stage_1_U2161141_9.jpg is (4252, 4252), but it must be 150x150.
#
# Image size of Stage_1_U2162049(1).jpg is (3024, 2778), but it must be 150x150.
#
# Image size of Stage_1_U2162049(10).jpg is (3024, 4032), but it must be 150x150.
#
# Image size of Stage_1_U2162049(2).jpg is (3024, 2955), but it must be 150x150.
#
# Image size of Stage_1_U2162049(3).jpg is (3024, 3390), but it must be 150x150.
#
# Image size of Stage_1_U2162049(4).jpg is (3024, 3195), but it must be 150x150.
#
# Image size of Stage_1_U2162049(5).jpg is (3024, 3280), but it must be 150x150.
#
# Image size of Stage_1_U2162049(6).jpg is (3118, 3024), but it must be 150x150.
#
# Image size of Stage_1_U2162049(7).jpg is (2822, 3651), but it must be 150x150.
#
# Image size of Stage_1_U2162049(8).jpg is (2495, 4032), but it must be 150x150.
#
# Image size of Stage_1_U2162049(9).jpg is (1814, 3648), but it must be 150x150.
#
# Image size of Stage_1_u2162252 (10).png is (155, 155), but it must be 150x150.
#
# Image size of Stage_1_u2162252 (2).png is (155, 155), but it must be 150x150.
#
# Image size of Stage_1_u2162252 (3).png is (155, 155), but it must be 150x150.
#
# Image size of Stage_1_u2162252 (4).png is (155, 155), but it must be 150x150.
#
# Image size of Stage_1_u2162252 (5).png is (155, 155), but it must be 150x150.
#
# Image size of Stage_1_u2162252 (6).png is (155, 155), but it must be 150x150.
#
# Image size of Stage_1_u2162252 (7).png is (155, 155), but it must be 150x150.
#
# Image size of Stage_1_u2162252 (8).png is (155, 155), but it must be 150x150.
#
# Image size of Stage_1_u2162252 (9).png is (155, 155), but it must be 150x150.
#
# Image size of Stage_1_u2162252.png is (155, 155), but it must be 150x150.
#
# Image size of Stage_1_U2187085_1.jpg is (300, 300), but it must be 150x150.
#
# Image size of Stage_1_U2187085_10.jpg is (300, 300), but it must be 150x150.
#
# Image size of Stage_1_U2187085_2.jpg is (300, 300), but it must be 150x150.
#
# Image size of Stage_1_U2187085_3.jpg is (300, 300), but it must be 150x150.
#
# Image size of Stage_1_U2187085_4.jpg is (300, 300), but it must be 150x150.
#
# Image size of Stage_1_U2187085_5.jpg is (300, 300), but it must be 150x150.
#
# Image size of Stage_1_U2187085_6.jpg is (300, 300), but it must be 150x150.
#
# Image size of Stage_1_U2187085_7.jpg is (300, 300), but it must be 150x150.
#
# Image size of Stage_1_U2187085_8.jpg is (300, 300), but it must be 150x150.
#
# Image size of Stage_1_U2187085_9.jpg is (300, 300), but it must be 150x150.
#
# Image size of Stage_1_U2261710.jpg (10).jpeg is (2016, 1512), but it must be 150x150.
#
# Image size of Stage_1_U2261710.jpg (2).jpeg is (2016, 1512), but it must be 150x150.
#
# Image size of Stage_1_U2261710.jpg (3).jpeg is (2016, 1512), but it must be 150x150.
#
# Image size of Stage_1_U2261710.jpg (4).jpeg is (2016, 1512), but it must be 150x150.
#
# Image size of Stage_1_U2261710.jpg (5).jpeg is (2016, 1512), but it must be 150x150.
#
# Image size of Stage_1_U2261710.jpg (6).jpeg is (2016, 1512), but it must be 150x150.
#
# Image size of Stage_1_U2261710.jpg (7).jpeg is (2016, 1512), but it must be 150x150.
#
# Image size of Stage_1_U2261710.jpg (8).jpeg is (2016, 1512), but it must be 150x150.
#
# Image size of Stage_1_U2261710.jpg (9).jpeg is (2016, 1512), but it must be 150x150.
#
# Image size of Stage_1_U2261710.jpg.jpeg is (2016, 1512), but it must be 150x150.
#
# Unable to open Image: Stage_1_U2265620(1).jpeg
#
# Unable to open Image: Stage_1_U2265620(10).jpg
#
# Unable to open Image: Stage_1_U2265620(2).jpg
#
# Unable to open Image: Stage_1_U2265620(3).jpg
#
# Unable to open Image: Stage_1_U2265620(4).jpg
#
# Unable to open Image: Stage_1_U2265620(5).jpg
#
# Unable to open Image: Stage_1_U2265620(6).jpg
#
# Unable to open Image: Stage_1_U2265620(7).jpg
#
# Unable to open Image: Stage_1_U2265620(8).jpg
#
# Unable to open Image: Stage_1_U2265620(9).jpg
#
# Image size of Stage_1_u2292637_001.jpg is (4000, 3000), but it must be 150x150.
#
# Image size of Stage_1_u2292637_002.jpg is (4000, 3000), but it must be 150x150.
#
# Image size of Stage_1_u2292637_003.jpg is (4000, 3000), but it must be 150x150.
#
# Image size of Stage_1_u2292637_004.jpg is (4000, 3000), but it must be 150x150.
#
# Image size of Stage_1_u2292637_005.jpg is (4000, 3000), but it must be 150x150.
#
# Image size of Stage_1_u2292637_006.jpg is (4000, 3000), but it must be 150x150.
#
# Image size of Stage_1_u2292637_007.jpg is (4000, 3000), but it must be 150x150.
#
# Image size of Stage_1_u2292637_008.jpg is (4000, 3000), but it must be 150x150.
#
# Image size of Stage_1_u2292637_009.jpg is (4000, 3000), but it must be 150x150.
#
# Image size of Stage_1_u2292637_010.jpg is (4000, 3000), but it must be 150x150.
#
# Image size of Stage_1_U2351103 .jpeg is (960, 934), but it must be 150x150.
#
# Image size of Step 1_ U2181868 .jpg is (4000, 3000), but it must be 150x150.
#
# Image size of Step1_ U2181868 (3).jpg is (4000, 3000), but it must be 150x150.
#
# Image size of Step1_ U2181868 (6).jpg is (4000, 3000), but it must be 150x150.
#
# Image size of Step1_ U2181868 (7).jpg is (4000, 3000), but it must be 150x150.
#
# Image size of Step1_ U2181868 (9).jpg is (4000, 3000), but it must be 150x150.
#
# Image size of Step1_ U2181868 .jpg is (4000, 3000), but it must be 150x150.
#
# Image size of Step1_ U2181868(10).jpg is (4000, 3000), but it must be 150x150.
#
# Image size of Step1_ U2181868(5).jpg is (4000, 3000), but it must be 150x150.
#
# Image size of Step1_ U2181868(8).jpg is (4000, 3000), but it must be 150x150.
#
# Image size of Step1_ U2181868.jpg is (4000, 3000), but it must be 150x150.
#
# Image size of 10_Stage_2_U2254663.jpg is (265, 338), but it must be 150x150.
#
# Image size of 1_Stage_2_U2254663.jpg is (285, 331), but it must be 150x150.
#
# Image size of 20241116_040613243_iOS.jpg is (117, 160), but it must be 150x150.
#
# Image size of 20241116_040813882_iOS.jpg is (119, 160), but it must be 150x150.
#
# Image size of 20241116_040900545_iOS.jpg is (119, 160), but it must be 150x150.
#
# Image size of 20241116_041023361_iOS.jpg is (119, 160), but it must be 150x150.
#
# Image size of 20241116_041129028_iOS.jpg is (119, 160), but it must be 150x150.
#
# Image size of 20241116_041239325_iOS.jpg is (119, 160), but it must be 150x150.
#
# Image size of 20241116_041331772_iOS.jpg is (119, 160), but it must be 150x150.
#
# Image size of 20241116_041413476_iOS.jpg is (119, 160), but it must be 150x150.
#
# Image size of 20241116_041459672_iOS.jpg is (119, 160), but it must be 150x150.
#
# Image size of 20241116_041601932_iOS.jpg is (119, 160), but it must be 150x150.
#
# 2_10_2162526.HEIC has invalid extension
#
# Image size of 2_10_2254417.jpg is (177, 177), but it must be 150x150.
#
# 2_1_2162526.HEIC has invalid extension
#
# Image size of 2_1_2254417.jpg is (177, 177), but it must be 150x150.
#
# 2_2_2162526.HEIC has invalid extension
#
# Image size of 2_2_2254417.jpg is (177, 177), but it must be 150x150.
#
# 2_3_2162526.HEIC has invalid extension
#
# Image size of 2_3_2254417.jpg is (177, 177), but it must be 150x150.
#
# 2_4_2162526.HEIC has invalid extension
#
# Image size of 2_4_2254417.jpg is (177, 177), but it must be 150x150.
#
# 2_5_2162526.HEIC has invalid extension
#
# Image size of 2_5_2254417.jpg is (177, 177), but it must be 150x150.
#
# 2_6_2162526.HEIC has invalid extension
#
# Image size of 2_6_2254417.jpg is (177, 177), but it must be 150x150.
#
# 2_7_2162526.HEIC has invalid extension
#
# Image size of 2_7_2254417.jpg is (177, 177), but it must be 150x150.
#
# 2_8_2162526.HEIC has invalid extension
#
# Image size of 2_8_2254417.jpg is (177, 177), but it must be 150x150.
#
# 2_9_2162526.HEIC has invalid extension
#
# Image size of 2_9_2254417.jpg is (177, 177), but it must be 150x150.
#
# Image size of 2_Stage_2_U2254663.jpg is (280, 201), but it must be 150x150.
#
# Image size of 3_Stage_2_u2254663.jpg is (281, 197), but it must be 150x150.
#
# Image size of 4_Stage_2_U2254663.jpg is (323, 229), but it must be 150x150.
#
# Image size of 5_Stage_2_U2254663.jpg is (286, 231), but it must be 150x150.
#
# Image size of 6_Stage_2_U2254663.jpg is (347, 245), but it must be 150x150.
#
# Image size of 7_Stage_2_U2254663.jpg is (379, 263), but it must be 150x150.
#
# Image size of 8_Stage_2_U2254663.jpg is (367, 324), but it must be 150x150.
#
# Image size of 9_Stage_2_U2254663.jpg is (239, 170), but it must be 150x150.
#
# Image size of Resized S 2-U2187423-1.jpg is (113, 150), but it must be 150x150.
#
# Image size of Resized S 2-U2187423-10.jpg is (113, 150), but it must be 150x150.
#
# Image size of Resized S 2-U2187423-2.jpg is (113, 150), but it must be 150x150.
#
# Image size of Resized S 2-U2187423-3.jpg is (113, 150), but it must be 150x150.
#
# Image size of Resized S 2-U2187423-4.jpg is (113, 150), but it must be 150x150.
#
# Image size of Resized S 2-U2187423-5.jpg is (113, 150), but it must be 150x150.
#
# Image size of Resized S 2-U2187423-6.jpg is (113, 150), but it must be 150x150.
#
# Image size of Resized S 2-U2187423-7.jpg is (113, 150), but it must be 150x150.
#
# Image size of Resized S 2-U2187423-8.jpg is (113, 150), but it must be 150x150.
#
# Image size of Resized S 2-U2187423-9.jpg is (113, 150), but it must be 150x150.
#
# Image size of stage 2 (u2187406).jpg is (3840, 5120), but it must be 150x150.
#
# Image size of stage 2 angle 7 U2266514.jpg is (113, 150), but it must be 150x150.
#
# Image size of Stage 2 angle1 U2266514.jpg is (113, 150), but it must be 150x150.
#
# Image size of Stage 2 angle2 U2266514.jpg is (113, 150), but it must be 150x150.
#
# Image size of Stage 2 angle3 U2266514.jpg is (113, 150), but it must be 150x150.
#
# Image size of Stage 2-2187423-1.jpg is (113, 150), but it must be 150x150.
#
# Image size of Stage 2-2187423-10.jpg is (113, 150), but it must be 150x150.
#
# Image size of Stage 2-2187423-2.jpg is (113, 150), but it must be 150x150.
#
# Image size of Stage 2-2187423-3.jpg is (113, 150), but it must be 150x150.
#
# Image size of Stage 2-2187423-5.jpg is (113, 150), but it must be 150x150.
#
# Image size of Stage 2-2187423-6.jpg is (113, 150), but it must be 150x150.
#
# Image size of Stage 2-2187423-7.jpg is (113, 150), but it must be 150x150.
#
# Image size of Stage 2-2187423-8.jpg is (113, 150), but it must be 150x150.
#
# Image size of Stage 2-2187423-9.jpg is (113, 150), but it must be 150x150.
#
# Image size of stage2 angle 10 U2266514.jpg is (113, 150), but it must be 150x150.
#
# Image size of stage2 angle 7 U2266514.jpg is (113, 150), but it must be 150x150.
#
# Image size of Stage2 angle4 U2266514.jpg is (113, 150), but it must be 150x150.
#
# Image size of stage2 angle5 U2266514.jpg is (113, 150), but it must be 150x150.
#
# Image size of stage2 angle6  U2266514.jpg is (113, 150), but it must be 150x150.
#
# Image size of stage2 angle8 U2266514.jpg is (113, 150), but it must be 150x150.
#
# Image size of stage2 angle9 U2266514.jpg is (113, 150), but it must be 150x150.
#
# Image size of Stage2 u2187422.jpg (2).jpg is (150, 200), but it must be 150x150.
#
# Image size of Stage2 u2187422.jpg (2)1.jpg is (150, 200), but it must be 150x150.
#
# Image size of stage2 U2187422.jpg (3).jpg is (150, 200), but it must be 150x150.
#
# Image size of stage2 U2187422.jpg (3)1.jpg is (150, 200), but it must be 150x150.
#
# Image size of stage2 u2187422.jpg (4).jpg is (150, 200), but it must be 150x150.
#
# Image size of stage2 u2187422.jpg (4)1.jpg is (150, 200), but it must be 150x150.
#
# Image size of stage2 u2187422.jpg (5).jpg is (150, 200), but it must be 150x150.
#
# Image size of stage2 u2187422.jpg (5)1.jpg is (150, 200), but it must be 150x150.
#
# Image size of stage2 u2187422.jpg (6).jpg is (150, 200), but it must be 150x150.
#
# Image size of stage2 u2187422.jpg (6)1.jpg is (150, 200), but it must be 150x150.
#
# Image size of stage2_u2353673 (10) copy.jpg is (750, 750), but it must be 150x150.
#
# Image size of stage2_u2353673 (3) copy.jpg is (750, 750), but it must be 150x150.
#
# Image size of stage2_u2353673 (4) copy.jpg is (750, 750), but it must be 150x150.
#
# Image size of stage2_u2353673 (5) copy.jpg is (750, 750), but it must be 150x150.
#
# Image size of stage2_u2353673 (6) copy.jpg is (750, 750), but it must be 150x150.
#
# Image size of stage2_u2353673 (7) copy.jpg is (750, 750), but it must be 150x150.
#
# Image size of stage2_u2353673 (8) copy.jpg is (750, 750), but it must be 150x150.
#
# Image size of stage2_u2353673 (9) copy.jpg is (750, 750), but it must be 150x150.
#
# Unable to open Image: stage2_u2353673(1) copy.jpg
#
# Unable to open Image: stage2_u2353673(2) copy.jpg
#
# Image size of Stage_02_U2174467_1.jpg is (800, 600), but it must be 150x150.
#
# Image size of Stage_02_U2174467_10.jpg is (800, 600), but it must be 150x150.
#
# Image size of Stage_02_U2174467_2.jpg is (800, 600), but it must be 150x150.
#
# Image size of Stage_02_U2174467_3.jpg is (800, 600), but it must be 150x150.
#
# Image size of Stage_02_U2174467_4.jpg is (800, 600), but it must be 150x150.
#
# Image size of Stage_02_U2174467_5.jpg is (800, 600), but it must be 150x150.
#
# Image size of Stage_02_U2174467_6.jpg is (800, 600), but it must be 150x150.
#
# Image size of Stage_02_U2174467_7.jpg is (800, 600), but it must be 150x150.
#
# Image size of Stage_02_U2174467_8.jpg is (800, 600), but it must be 150x150.
#
# Image size of Stage_02_U2174467_9.jpg is (800, 600), but it must be 150x150.
#
# Image size of Stage_2.10_u2352832.jpg is (3072, 3072), but it must be 150x150.
#
# Image size of Stage_2.1_u2352832.jpg is (3072, 3072), but it must be 150x150.
#
# Image size of Stage_2.2_u2352832.jpg is (3072, 3071), but it must be 150x150.
#
# Image size of Stage_2.3_u2352832.jpg is (3072, 3072), but it must be 150x150.
#
# Image size of Stage_2.4_u2352832.jpg is (3072, 3072), but it must be 150x150.
#
# Image size of Stage_2.5_u2352832.jpg is (3072, 3072), but it must be 150x150.
#
# Image size of Stage_2.6_u2352832.jpg is (3072, 3072), but it must be 150x150.
#
# Image size of Stage_2.7_u2352832.jpg is (3072, 3072), but it must be 150x150.
#
# Image size of Stage_2.8_u2352832.jpg is (3072, 3072), but it must be 150x150.
#
# Image size of Stage_2.9_u2352832.jpg is (3072, 3072), but it must be 150x150.
#
# Image size of Stage_2_2452781(1).jpg is (1153, 1245), but it must be 150x150.
#
# Image size of Stage_2_2452781(10).jpg is (1161, 1355), but it must be 150x150.
#
# Image size of stage_2_2452781(2).jpg is (1128, 1184), but it must be 150x150.
#
# Image size of Stage_2_2452781(3).jpg is (1138, 1010), but it must be 150x150.
#
# Image size of Stage_2_2452781(4).jpg is (1145, 1066), but it must be 150x150.
#
# Image size of Stage_2_2452781(5).jpg is (1179, 1087), but it must be 150x150.
#
# Image size of Stage_2_2452781(6).jpg is (1179, 1170), but it must be 150x150.
#
# Image size of Stage_2_2452781(7).jpg is (1158, 1196), but it must be 150x150.
#
# Image size of Stage_2_2452781(8).jpg is (1176, 1150), but it must be 150x150.
#
# Image size of Stage_2_2452781(9).jpg is (1179, 1018), but it must be 150x150.
#
# Image size of Stage_2_U2161141_1.jpg is (4252, 4252), but it must be 150x150.
#
# Image size of Stage_2_U2161141_10.jpg is (4252, 4252), but it must be 150x150.
#
# Image size of Stage_2_U2161141_2.jpg is (4252, 4252), but it must be 150x150.
#
# Image size of Stage_2_U2161141_3.jpg is (4252, 4252), but it must be 150x150.
#
# Image size of Stage_2_U2161141_4.jpg is (4252, 4252), but it must be 150x150.
#
# Image size of Stage_2_U2161141_5.jpg is (4252, 4252), but it must be 150x150.
#
# Image size of Stage_2_U2161141_6.jpg is (4252, 4252), but it must be 150x150.
#
# Image size of Stage_2_U2161141_7.jpg is (4252, 4252), but it must be 150x150.
#
# Image size of Stage_2_U2161141_8.jpg is (4252, 4252), but it must be 150x150.
#
# Image size of Stage_2_U2161141_9.jpg is (4252, 4252), but it must be 150x150.
#
# Image size of Stage_2_U2162049(1).jpeg is (2275, 3436), but it must be 150x150.
#
# Image size of Stage_2_U2162049(10).jpeg is (3024, 4032), but it must be 150x150.
#
# Image size of Stage_2_U2162049(2).jpeg is (3024, 4032), but it must be 150x150.
#
# Image size of Stage_2_U2162049(3).jpeg is (3024, 4032), but it must be 150x150.
#
# Image size of Stage_2_U2162049(4).jpeg is (3024, 3694), but it must be 150x150.
#
# Image size of Stage_2_U2162049(5).jpeg is (3024, 3651), but it must be 150x150.
#
# Image size of Stage_2_U2162049(6).jpeg is (3024, 4032), but it must be 150x150.
#
# Image size of Stage_2_U2162049(7).jpeg is (3024, 4032), but it must be 150x150.
#
# Image size of Stage_2_U2162049(8).jpeg is (3024, 4032), but it must be 150x150.
#
# Image size of Stage_2_U2162049(9).jpeg is (3024, 4032), but it must be 150x150.
#
# Image size of Stage_2_u2162252 (10).png is (155, 155), but it must be 150x150.
#
# Image size of Stage_2_u2162252 (2).png is (155, 155), but it must be 150x150.
#
# Image size of Stage_2_u2162252 (3).png is (155, 155), but it must be 150x150.
#
# Image size of Stage_2_u2162252 (4).png is (155, 155), but it must be 150x150.
#
# Image size of Stage_2_u2162252 (5).png is (155, 155), but it must be 150x150.
#
# Image size of Stage_2_u2162252 (6).png is (155, 155), but it must be 150x150.
#
# Image size of Stage_2_u2162252 (7).png is (155, 155), but it must be 150x150.
#
# Image size of Stage_2_u2162252 (8).png is (155, 155), but it must be 150x150.
#
# Image size of Stage_2_u2162252 (9).png is (155, 155), but it must be 150x150.
#
# Image size of Stage_2_u2162252.png is (155, 155), but it must be 150x150.
#
# Image size of Stage_2_U2187085_1.jpg is (300, 300), but it must be 150x150.
#
# Image size of Stage_2_U2187085_10.jpg is (300, 300), but it must be 150x150.
#
# Image size of Stage_2_U2187085_2.jpg is (300, 300), but it must be 150x150.
#
# Image size of Stage_2_U2187085_3.jpg is (300, 300), but it must be 150x150.
#
# Image size of Stage_2_U2187085_4.jpg is (300, 300), but it must be 150x150.
#
# Image size of Stage_2_U2187085_5.jpg is (300, 300), but it must be 150x150.
#
# Image size of Stage_2_U2187085_6.jpg is (300, 300), but it must be 150x150.
#
# Image size of Stage_2_U2187085_7.jpg is (300, 300), but it must be 150x150.
#
# Image size of Stage_2_U2187085_8.jpg is (300, 300), but it must be 150x150.
#
# Image size of Stage_2_U2261710.jpg (10).jpeg is (1512, 2016), but it must be 150x150.
#
# Image size of Stage_2_U2261710.jpg (2).jpeg is (2016, 1512), but it must be 150x150.
#
# Image size of Stage_2_U2261710.jpg (3).jpeg is (2016, 1512), but it must be 150x150.
#
# Image size of Stage_2_U2261710.jpg (4).jpeg is (2016, 1512), but it must be 150x150.
#
# Image size of Stage_2_U2261710.jpg (5).jpeg is (2016, 1512), but it must be 150x150.
#
# Image size of Stage_2_U2261710.jpg (6).jpeg is (2016, 1512), but it must be 150x150.
#
# Image size of Stage_2_U2261710.jpg (7).jpeg is (2016, 1512), but it must be 150x150.
#
# Image size of Stage_2_U2261710.jpg (8).jpeg is (2016, 1512), but it must be 150x150.
#
# Image size of Stage_2_U2261710.jpg (9).jpeg is (2016, 1512), but it must be 150x150.
#
# Image size of Stage_2_U2261710.jpg.jpeg is (1512, 2016), but it must be 150x150.
#
# Unable to open Image: Stage_2_U2265620(1).jpeg
#
# Unable to open Image: Stage_2_U2265620(10).jpeg
#
# Unable to open Image: Stage_2_U2265620(2).jpeg
#
# Unable to open Image: Stage_2_U2265620(3).jpeg
#
# Unable to open Image: Stage_2_U2265620(4).jpeg
#
# Unable to open Image: Stage_2_U2265620(5).jpeg
#
# Unable to open Image: Stage_2_U2265620(6).jpeg
#
# Unable to open Image: Stage_2_U2265620(7).jpeg
#
# Unable to open Image: Stage_2_U2265620(8).jpeg
#
# Unable to open Image: Stage_2_U2265620(9).jpeg
#
# Unable to open Image: stage_2_u2266497(10).jpg
#
# Unable to open Image: stage_2_u2266497(3).jpg
#
# Unable to open Image: stage_2_u2266497(4).jpg
#
# Unable to open Image: stage_2_u2266497(6).jpg
#
# Unable to open Image: stage_2_u2266497(8).jpg
#
# Unable to open Image: stage_2_u2266497.jpg
#
# Image size of Stage_2_u2292637_001.jpg is (4000, 3000), but it must be 150x150.
#
# Image size of Stage_2_u2292637_002.jpg is (4000, 3000), but it must be 150x150.
#
# Image size of Stage_2_u2292637_003.jpg is (4000, 3000), but it must be 150x150.
#
# Image size of Stage_2_u2292637_004.jpg is (4000, 3000), but it must be 150x150.
#
# Image size of Stage_2_u2292637_005.jpg is (4000, 3000), but it must be 150x150.
#
# Image size of Stage_2_u2292637_006.jpg is (4000, 3000), but it must be 150x150.
#
# Image size of Stage_2_u2292637_007.jpg is (4000, 3000), but it must be 150x150.
#
# Image size of Stage_2_u2292637_008.jpg is (4000, 3000), but it must be 150x150.
#
# Image size of Stage_2_u2292637_009.jpg is (4000, 3000), but it must be 150x150.
#
# Image size of Stage_2_u2292637_010.jpg is (4000, 3000), but it must be 150x150.
#
# Image size of Stage_2_U2351103 .jpeg is (959, 837), but it must be 150x150.
#
# Image size of Step2_ U2181868 (1).jpg is (4000, 3000), but it must be 150x150.
#
# Image size of Step2_ U2181868 (10).jpg is (4000, 3000), but it must be 150x150.
#
# Image size of Step2_ U2181868 (2).jpg is (4000, 3000), but it must be 150x150.
#
# Image size of Step2_ U2181868 (3).jpg is (4000, 3000), but it must be 150x150.
#
# Image size of Step2_ U2181868 (4).jpg is (4000, 3000), but it must be 150x150.
#
# Image size of Step2_ U2181868 (5).jpg is (4000, 3000), but it must be 150x150.
#
# Image size of Step2_ U2181868 (6).jpg is (4000, 3000), but it must be 150x150.
#
# Image size of Step2_ U2181868 (7).jpg is (4000, 3000), but it must be 150x150.
#
# Image size of Step2_ U2181868 (8).jpg is (4000, 3000), but it must be 150x150.
#
# Image size of Step2_ U2181868 (9).jpg is (4000, 3000), but it must be 150x150.
#
# Image size of Step3_ U2181868 (1).jpg is (4000, 3000), but it must be 150x150.
#
# Image size of Step3_ U2181868 (10).jpg is (4000, 3000), but it must be 150x150.
#
# Image size of Step3_ U2181868 (2).jpg is (4000, 3000), but it must be 150x150.
#
# Image size of Step3_ U2181868 (3).jpg is (4000, 3000), but it must be 150x150.
#
# Image size of Step3_ U2181868 (4).jpg is (4000, 3000), but it must be 150x150.
#
# Image size of Step3_ U2181868 (5).jpg is (4000, 3000), but it must be 150x150.
#
# Image size of Step3_ U2181868 (6)-1.jpg is (4000, 3000), but it must be 150x150.
#
# Image size of Step3_ U2181868 (6).jpg is (4000, 3000), but it must be 150x150.
#
# Image size of Step3_ U2181868 (7).jpg is (4000, 3000), but it must be 150x150.
#
# Image size of Step3_ U2181868 (8).jpg is (4000, 3000), but it must be 150x150.
#
# Image size of 10_Stage_3_U2254663.jpg is (343, 282), but it must be 150x150.
#
# Image size of 1_Stage_3_U2254663.jpg is (286, 363), but it must be 150x150.
#
# Image size of 20241116_041828990_iOS.jpg is (119, 160), but it must be 150x150.
#
# Image size of 20241116_041912131_iOS.jpg is (119, 160), but it must be 150x150.
#
# Image size of 20241116_042006627_iOS.jpg is (119, 160), but it must be 150x150.
#
# Image size of 20241116_042056138_iOS.jpg is (119, 160), but it must be 150x150.
#
# Image size of 20241116_042141398_iOS.jpg is (119, 160), but it must be 150x150.
#
# Image size of 20241116_042247160_iOS.jpg is (119, 160), but it must be 150x150.
#
# Image size of 20241116_042350243_iOS.jpg is (119, 160), but it must be 150x150.
#
# Image size of 20241116_042430003_iOS.jpg is (119, 160), but it must be 150x150.
#
# Image size of 20241116_042512174_iOS.jpg is (119, 160), but it must be 150x150.
#
# Image size of 20241116_042554567_iOS.jpg is (119, 160), but it must be 150x150.
#
# Image size of 2_Stage_3_U2254663.jpg is (318, 387), but it must be 150x150.
#
# 3_10_2162526.HEIC has invalid extension
#
# Image size of 3_10_2254417.jpg is (177, 177), but it must be 150x150.
#
# 3_1_2162526.HEIC has invalid extension
#
# Image size of 3_1_2254417.jpg is (177, 177), but it must be 150x150.
#
# 3_2_2162526.HEIC has invalid extension
#
# Image size of 3_2_2254417.jpg is (177, 177), but it must be 150x150.
#
# 3_3_2162526.HEIC has invalid extension
#
# Image size of 3_3_2254417.jpg is (177, 177), but it must be 150x150.
#
# 3_4_2162526.HEIC has invalid extension
#
# Image size of 3_4_2254417.jpg is (177, 177), but it must be 150x150.
#
# 3_5_2162526.HEIC has invalid extension
#
# Image size of 3_5_2254417.jpg is (177, 177), but it must be 150x150.
#
# 3_6_2162526.HEIC has invalid extension
#
# Image size of 3_6_2254417.jpg is (177, 177), but it must be 150x150.
#
# 3_7_2162526.HEIC has invalid extension
#
# Image size of 3_7_2254417.jpg is (177, 177), but it must be 150x150.
#
# 3_8_2162526.HEIC has invalid extension
#
# Image size of 3_8_2254417.jpg is (177, 177), but it must be 150x150.
#
# 3_9_2162526.HEIC has invalid extension
#
# Image size of 3_9_2254417.jpg is (177, 177), but it must be 150x150.
#
# Image size of 3_Stage_3_U2254663.jpg is (376, 384), but it must be 150x150.
#
# Image size of 4_Stage_3_U2254663.jpg is (257, 222), but it must be 150x150.
#
# Image size of 5_Stage_3_U2254663.jpg is (306, 256), but it must be 150x150.
#
# Image size of 6_Stage_3_U2254663.jpg is (305, 264), but it must be 150x150.
#
# Image size of 7_Stage_3_U2254663.jpg is (328, 291), but it must be 150x150.
#
# Image size of 8_Stage_3_U2254663.jpg is (292, 261), but it must be 150x150.
#
# Image size of 9_Stage_3_U2254663.jpg is (313, 271), but it must be 150x150.
#
# Image size of Resized S 3-U2187423-1.jpg is (113, 150), but it must be 150x150.
#
# Image size of Resized S 3-U2187423-10.jpg is (113, 150), but it must be 150x150.
#
# Image size of Resized S 3-U2187423-2.jpg is (113, 150), but it must be 150x150.
#
# Image size of Resized S 3-U2187423-3.jpg is (113, 150), but it must be 150x150.
#
# Image size of Resized S 3-U2187423-4.jpg is (113, 150), but it must be 150x150.
#
# Image size of Resized S 3-U2187423-5.jpg is (113, 150), but it must be 150x150.
#
# Image size of Resized S 3-U2187423-6.jpg is (113, 150), but it must be 150x150.
#
# Image size of Resized S 3-U2187423-7.jpg is (113, 150), but it must be 150x150.
#
# Image size of Resized S 3-U2187423-8.jpg is (113, 150), but it must be 150x150.
#
# Image size of Resized S 3-U2187423-9.jpg is (113, 150), but it must be 150x150.
#
# Image size of stage 3 (u2187406).jpg is (3840, 5120), but it must be 150x150.
#
# Image size of Stage 3 angle 1 U2266514.jpg is (113, 150), but it must be 150x150.
#
# Image size of Stage 3 angle 1.jpg is (3024, 4032), but it must be 150x150.
#
# Image size of stage 3 angle 10 U2266514.jpg is (113, 150), but it must be 150x150.
#
# Image size of stage 3 angle 10.jpg is (3024, 4032), but it must be 150x150.
#
# Image size of stage 3 angle 6 U2266514.jpg is (113, 150), but it must be 150x150.
#
# Image size of stage 3 angle 6.jpg is (3024, 4032), but it must be 150x150.
#
# Image size of stage 3 angle 7 U2266514.jpg is (3024, 4032), but it must be 150x150.
#
# Image size of stage 3 angle 7.jpg is (3024, 4032), but it must be 150x150.
#
# Image size of stage 3 angle 8 U2266514.jpg is (113, 150), but it must be 150x150.
#
# Image size of stage 3 angle 8.jpg is (3024, 4032), but it must be 150x150.
#
# Image size of Stage 3 angle2 U2266514.jpg is (113, 150), but it must be 150x150.
#
# Image size of Stage 3 angle2.jpg is (3024, 4032), but it must be 150x150.
#
# Image size of Stage 3 angle3 U2266514.jpg is (113, 150), but it must be 150x150.
#
# Image size of Stage 3 angle3.jpg is (3024, 4032), but it must be 150x150.
#
# Image size of Stage 3 angle4 U2266514.jpg is (113, 150), but it must be 150x150.
#
# Image size of Stage 3 angle4.jpg is (3024, 4032), but it must be 150x150.
#
# Image size of Stage 3 angle5 U2266514.jpg is (3024, 4032), but it must be 150x150.
#
# Image size of Stage 3 angle5.jpg is (3024, 4032), but it must be 150x150.
#
# Image size of stage 3 angle9 U2266514.jpg is (113, 150), but it must be 150x150.
#
# Image size of stage 3 angle9.jpg is (3024, 4032), but it must be 150x150.
#
# Image size of Stage 3-2187423-1.jpg is (1200, 1600), but it must be 150x150.
#
# Image size of Stage 3-2187423-10.jpg is (1200, 1600), but it must be 150x150.
#
# Image size of Stage 3-2187423-2.jpg is (1200, 1600), but it must be 150x150.
#
# Image size of Stage 3-2187423-3.jpg is (1200, 1600), but it must be 150x150.
#
# Image size of Stage 3-2187423-4.jpg is (1200, 1600), but it must be 150x150.
#
# Image size of Stage 3-2187423-5.jpg is (1200, 1600), but it must be 150x150.
#
# Image size of Stage 3-2187423-6.jpg is (1200, 1600), but it must be 150x150.
#
# Image size of Stage 3-2187423-7.jpg is (1200, 1600), but it must be 150x150.
#
# Image size of Stage 3-2187423-8.jpg is (1200, 1600), but it must be 150x150.
#
# Image size of Stage 3-2187423-9.jpg is (1200, 1600), but it must be 150x150.
#
# Image size of stage3 u2187422.jpg (10).jpg is (150, 200), but it must be 150x150.
#
# Image size of stage3 u2187422.jpg (2).jpg is (150, 200), but it must be 150x150.
#
# Image size of stage3 u2187422.jpg (3).jpg is (150, 200), but it must be 150x150.
#
# Image size of stage3 u2187422.jpg (4).jpg is (150, 200), but it must be 150x150.
#
# Image size of stage3 u2187422.jpg (5).jpg is (150, 200), but it must be 150x150.
#
# Image size of stage3 u2187422.jpg (6).jpg is (150, 200), but it must be 150x150.
#
# Image size of stage3 u2187422.jpg (7).jpg is (150, 200), but it must be 150x150.
#
# Image size of stage3 u2187422.jpg (8).jpg is (150, 200), but it must be 150x150.
#
# Image size of stage3 u2187422.jpg (9).jpg is (150, 200), but it must be 150x150.
#
# Image size of stage3 u2187422.jpg.jpg is (150, 200), but it must be 150x150.
#
# Image size of stage3_u2353673(1) copy.jpg is (750, 750), but it must be 150x150.
#
# Image size of stage3_u2353673(10) copy.jpg is (750, 750), but it must be 150x150.
#
# Image size of stage3_u2353673(2) copy.jpg is (750, 750), but it must be 150x150.
#
# Image size of stage3_u2353673(3) copy.jpg is (750, 750), but it must be 150x150.
#
# Image size of stage3_u2353673(4) copy.jpg is (750, 750), but it must be 150x150.
#
# Image size of stage3_u2353673(5) copy.jpg is (750, 750), but it must be 150x150.
#
# Image size of stage3_u2353673(6) copy.jpg is (750, 750), but it must be 150x150.
#
# Image size of stage3_u2353673(7) copy.jpg is (750, 750), but it must be 150x150.
#
# Image size of stage3_u2353673(8) copy.jpg is (750, 750), but it must be 150x150.
#
# Image size of stage3_u2353673(9) copy.jpg is (750, 750), but it must be 150x150.
#
# Image size of Stage_3.10_u2352832.jpg is (3072, 3072), but it must be 150x150.
#
# Image size of Stage_3.1_u2352832.jpg is (3072, 3072), but it must be 150x150.
#
# Image size of Stage_3.2_u2352832.jpg is (3072, 3072), but it must be 150x150.
#
# Image size of Stage_3.3_u2352832.jpg is (3072, 3072), but it must be 150x150.
#
# Image size of Stage_3.4_u2352832.jpg is (3072, 3072), but it must be 150x150.
#
# Image size of Stage_3.5_u2352832.jpg is (3072, 3072), but it must be 150x150.
#
# Image size of Stage_3.6_u2352832.jpg is (3072, 3072), but it must be 150x150.
#
# Image size of Stage_3.7_u2352832.jpg is (3072, 3072), but it must be 150x150.
#
# Image size of Stage_3.8_u2352832.jpg is (3072, 3072), but it must be 150x150.
#
# Image size of Stage_3.9_u2352832.jpg is (3072, 3071), but it must be 150x150.
#
# Image size of Stage_3_2452781(1).jpg is (1179, 1085), but it must be 150x150.
#
# Image size of Stage_3_2452781(10).jpg is (1179, 1194), but it must be 150x150.
#
# Image size of Stage_3_2452781(2).jpg is (1125, 977), but it must be 150x150.
#
# Image size of Stage_3_2452781(3).jpg is (1169, 1031), but it must be 150x150.
#
# Image size of Stage_3_2452781(4).jpg is (1137, 1108), but it must be 150x150.
#
# Image size of Stage_3_2452781(5).jpg is (1177, 990), but it must be 150x150.
#
# Image size of Stage_3_2452781(6).jpg is (1171, 1051), but it must be 150x150.
#
# Image size of Stage_3_2452781(7).jpg is (1154, 1171), but it must be 150x150.
#
# Image size of Stage_3_2452781(8).jpg is (1179, 916), but it must be 150x150.
#
# Image size of Stage_3_2452781(9).jpg is (1179, 978), but it must be 150x150.
#
# Image size of Stage_3_U2161141_1.jpg is (4252, 4252), but it must be 150x150.
#
# Image size of Stage_3_U2161141_10.jpg is (4252, 4252), but it must be 150x150.
#
# Image size of Stage_3_U2161141_2.jpg is (4252, 4252), but it must be 150x150.
#
# Image size of Stage_3_U2161141_3.jpg is (4252, 4252), but it must be 150x150.
#
# Image size of Stage_3_U2161141_4.jpg is (4252, 4252), but it must be 150x150.
#
# Image size of Stage_3_U2161141_5.jpg is (4252, 4252), but it must be 150x150.
#
# Image size of Stage_3_U2161141_6.jpg is (4252, 4252), but it must be 150x150.
#
# Image size of Stage_3_U2161141_7.jpg is (4252, 4252), but it must be 150x150.
#
# Image size of Stage_3_U2161141_8.jpg is (4252, 4252), but it must be 150x150.
#
# Image size of Stage_3_U2161141_9.jpg is (4252, 4252), but it must be 150x150.
#
# Image size of Stage_3_U2162049(1).jpeg is (3024, 4032), but it must be 150x150.
#
# Image size of Stage_3_U2162049(10).jpeg is (4032, 3024), but it must be 150x150.
#
# Image size of Stage_3_U2162049(2).jpeg is (3024, 4032), but it must be 150x150.
#
# Image size of Stage_3_U2162049(3).jpeg is (3024, 4032), but it must be 150x150.
#
# Image size of Stage_3_U2162049(4).jpeg is (3024, 4032), but it must be 150x150.
#
# Image size of Stage_3_U2162049(5).jpeg is (2853, 3669), but it must be 150x150.
#
# Image size of Stage_3_U2162049(6).jpeg is (3024, 4032), but it must be 150x150.
#
# Image size of Stage_3_U2162049(7).jpeg is (3024, 4032), but it must be 150x150.
#
# Image size of Stage_3_U2162049(8).jpeg is (4032, 3024), but it must be 150x150.
#
# Image size of Stage_3_U2162049(9).jpeg is (4032, 3024), but it must be 150x150.
#
# Image size of Stage_3_u2162252 (10).png is (155, 155), but it must be 150x150.
#
# Image size of Stage_3_u2162252 (2).png is (155, 155), but it must be 150x150.
#
# Image size of Stage_3_u2162252 (3).png is (155, 155), but it must be 150x150.
#
# Image size of Stage_3_u2162252 (4).png is (155, 155), but it must be 150x150.
#
# Image size of Stage_3_u2162252 (5).png is (155, 155), but it must be 150x150.
#
# Image size of Stage_3_u2162252 (6).png is (155, 155), but it must be 150x150.
#
# Image size of Stage_3_u2162252 (7).png is (155, 155), but it must be 150x150.
#
# Image size of Stage_3_u2162252 (8).png is (155, 155), but it must be 150x150.
#
# Image size of Stage_3_u2162252 (9).png is (155, 155), but it must be 150x150.
#
# Image size of Stage_3_u2162252.png is (155, 155), but it must be 150x150.
#
# Image size of Stage_3_U2187085_1.jpg is (300, 300), but it must be 150x150.
#
# Image size of Stage_3_U2187085_10.jpg is (300, 300), but it must be 150x150.
#
# Image size of Stage_3_U2187085_2.jpg is (300, 300), but it must be 150x150.
#
# Image size of Stage_3_U2187085_3.jpg is (300, 300), but it must be 150x150.
#
# Image size of Stage_3_U2187085_4.jpg is (300, 300), but it must be 150x150.
#
# Image size of Stage_3_U2187085_5.jpg is (300, 300), but it must be 150x150.
#
# Image size of Stage_3_U2187085_7.jpg is (300, 300), but it must be 150x150.
#
# Image size of Stage_3_U2187085_8.jpg is (300, 300), but it must be 150x150.
#
# Image size of Stage_3_U2187085_9.jpg is (300, 300), but it must be 150x150.
#
# Image size of Stage_3_U2261710.jpg (10).jpeg is (1512, 2016), but it must be 150x150.
#
# Image size of Stage_3_U2261710.jpg (2).jpeg is (1512, 2016), but it must be 150x150.
#
# Image size of Stage_3_U2261710.jpg (3).jpeg is (1512, 2016), but it must be 150x150.
#
# Image size of Stage_3_U2261710.jpg (4).jpeg is (1512, 2016), but it must be 150x150.
#
# Image size of Stage_3_U2261710.jpg (5).jpeg is (1512, 2016), but it must be 150x150.
#
# Image size of Stage_3_U2261710.jpg (6).jpeg is (1512, 2016), but it must be 150x150.
#
# Image size of Stage_3_U2261710.jpg (7).jpeg is (1512, 2016), but it must be 150x150.
#
# Image size of Stage_3_U2261710.jpg (8).jpeg is (1512, 2016), but it must be 150x150.
#
# Image size of Stage_3_U2261710.jpg (9).jpeg is (1512, 2016), but it must be 150x150.
#
# Image size of Stage_3_U2261710.jpg.jpeg is (1512, 2016), but it must be 150x150.
#
# Unable to open Image: Stage_3_U2265620(1).jpeg
#
# Unable to open Image: Stage_3_U2265620(10).jpeg
#
# Unable to open Image: Stage_3_U2265620(2).jpeg
#
# Unable to open Image: Stage_3_U2265620(3).jpeg
#
# Unable to open Image: Stage_3_U2265620(4).jpeg
#
# Unable to open Image: Stage_3_U2265620(5).jpeg
#
# Unable to open Image: Stage_3_U2265620(6).jpeg
#
# Unable to open Image: Stage_3_U2265620(7).jpeg
#
# Unable to open Image: Stage_3_U2265620(8).jpeg
#
# Unable to open Image: Stage_3_U2265620(9).jpeg
#
# Image size of Stage_3_U2266219(7).jpeg is (113, 150), but it must be 150x150.
#
# Unable to open Image: Stage_3_u2266497(3).jpg
#
# Unable to open Image: Stage_3_u2266497(5).jpg
#
# Unable to open Image: Stage_3_u2266497(7).jpg
#
# Unable to open Image: Stage_3_u2266497(9).jpg
#
# Unable to open Image: Stage_3_u2266497.JPG
#
# Image size of Stage_3_u2292637_001.jpg is (4000, 3000), but it must be 150x150.
#
# Image size of Stage_3_u2292637_002.jpg is (4000, 3000), but it must be 150x150.
#
# Image size of Stage_3_u2292637_003.jpg is (4000, 3000), but it must be 150x150.
#
# Image size of Stage_3_u2292637_004.jpg is (4000, 3000), but it must be 150x150.
#
# Image size of Stage_3_u2292637_005.jpg is (4000, 3000), but it must be 150x150.
#
# Image size of Stage_3_u2292637_006.jpg is (4000, 3000), but it must be 150x150.
#
# Image size of Stage_3_u2292637_007.jpg is (4000, 3000), but it must be 150x150.
#
# Image size of Stage_3_u2292637_008.jpg is (4000, 3000), but it must be 150x150.
#
# Image size of Stage_3_u2292637_009.jpg is (4000, 3000), but it must be 150x150.
#
# Image size of Stage_3_u2292637_010.jpg is (4000, 3000), but it must be 150x150.
#
# Image size of Stage_3_U2351103 .jpeg is (959, 1003), but it must be 150x150.
#
# Image size of 10_Stage_4_U2254663.jpg is (284, 258), but it must be 150x150.
#
# Image size of 1_Stage_4_U2254663.jpg is (277, 280), but it must be 150x150.
#
# Image size of 20241116_042918931_iOS.jpg is (119, 160), but it must be 150x150.
#
# Image size of 20241116_043015780_iOS.jpg is (119, 160), but it must be 150x150.
#
# Image size of 20241116_043104135_iOS.jpg is (119, 160), but it must be 150x150.
#
# Image size of 20241116_043212697_iOS.jpg is (119, 160), but it must be 150x150.
#
# Image size of 20241116_043256463_iOS.jpg is (119, 160), but it must be 150x150.
#
# Image size of 20241116_043346404_iOS.jpg is (119, 160), but it must be 150x150.
#
# Image size of 20241116_043452120_iOS.jpg is (119, 160), but it must be 150x150.
#
# Image size of 20241116_043557167_iOS.jpg is (119, 160), but it must be 150x150.
#
# Image size of 20241116_043650124_iOS.jpg is (119, 160), but it must be 150x150.
#
# Image size of 20241116_043733731_iOS.jpg is (119, 160), but it must be 150x150.
#
# Image size of 2_Stage_4_U2254663.jpg is (259, 265), but it must be 150x150.
#
# Image size of 3_Stage_4_U2254663.jpg is (271, 260), but it must be 150x150.
#
# 4_10_2162526.HEIC has invalid extension
#
# Image size of 4_10_2254417.jpg is (177, 177), but it must be 150x150.
#
# 4_1_2162526.HEIC has invalid extension
#
# ...
#
# Image size of Stage_7_u2292637_009.jpg is (4000, 3000), but it must be 150x150.
#
# Image size of Stage_7_u2292637_010.jpg is (4000, 3000), but it must be 150x150.
#
# Image size of Stage_7_U2351103 .jpeg is (960, 892), but it must be 150x150.
#
# Image size of Stage_7_u2354703(6).JPG is (112, 150), but it must be 150x150.
#
# Image size of Stage_7_U2354939(9)_resized.jpg is (112, 150), but it must be 150x150.
#
# Image size of Step7_ U2181868(1)_002122.jpg is (4000, 3000), but it must be 150x150.
#
# Image size of Step7_ U2181868(10).jpg is (4000, 3000), but it must be 150x150.
#
# Image size of Step7_ U2181868(2).jpg is (4000, 3000), but it must be 150x150.
#
# Image size of Step7_ U2181868(3).jpg is (4000, 3000), but it must be 150x150.
#
# Image size of Step7_ U2181868(4).jpg is (4000, 3000), but it must be 150x150.
#
# Image size of Step7_ U2181868(5).jpg is (4000, 3000), but it must be 150x150.
#
# Image size of Step7_ U2181868(6).jpg is (4000, 3000), but it must be 150x150.
#
# Image size of Step7_ U2181868(7).jpg is (4000, 3000), but it must be 150x150.
#
# Image size of Step7_ U2181868(8).jpg is (4000, 3000), but it must be 150x150.
#
# Image size of Step7_ U2181868(9).jpg is (4000, 3000), but it must be 150x150.
#
# Image size of 10_Stage_8_U2182091.jpg is (3024, 4032), but it must be 150x150.
#
# Image size of 10_Stage_8_U2254663.jpg is (452, 391), but it must be 150x150.
#
# Image size of 1_Stage_8_U2182091.jpg is (3024, 4032), but it must be 150x150.
#
# Image size of 1_Stage_8_U2254663.jpg is (352, 352), but it must be 150x150.
#
# Image size of 20241116_232801453_iOS.jpg is (119, 160), but it must be 150x150.
#
# Image size of 20241116_232844670_iOS.jpg is (119, 160), but it must be 150x150.
#
# Image size of 20241116_232927177_iOS.jpg is (119, 160), but it must be 150x150.
#
# Image size of 20241116_233000722_iOS.jpg is (119, 160), but it must be 150x150.
#
# Image size of 20241116_233350210_iOS.jpg is (119, 160), but it must be 150x150.
#
# Image size of 20241116_233439038_iOS.jpg is (119, 160), but it must be 150x150.
#
# Image size of 20241116_233555368_iOS.jpg is (119, 160), but it must be 150x150.
#
# Image size of 20241116_233653968_iOS.jpg is (119, 160), but it must be 150x150.
#
# Image size of 20241116_233747011_iOS.jpg is (119, 160), but it must be 150x150.
#
# Image size of 20241116_233904100_iOS.jpg is (200, 150), but it must be 150x150.
#
# Image size of 2_Stage_8_U2182091.jpg is (3024, 4032), but it must be 150x150.
#
# Image size of 2_Stage_8_U2254663.jpg is (361, 354), but it must be 150x150.
#
# Image size of 3_Stage_8_U2182091.jpg is (3024, 4032), but it must be 150x150.
#
# Image size of 3_Stage_8_U2254663.jpg is (398, 271), but it must be 150x150.
#
# Image size of 4_Stage_8_U2182091.jpg is (3024, 4032), but it must be 150x150.
#
# Image size of 4_Stage_8_U2254663.jpg is (443, 279), but it must be 150x150.
#
# Image size of 5_Stage_8_U2182091.jpg is (4032, 3024), but it must be 150x150.
#
# Image size of 5_Stage_8_U2254663.jpg is (390, 262), but it must be 150x150.
#
# Image size of 6_Stage_8_U2182091.jpg is (3024, 4032), but it must be 150x150.
#
# Image size of 6_Stage_8_U2254663.jpg is (390, 291), but it must be 150x150.
#
# Image size of 7_Stage_8_U2182091.jpg is (3024, 4032), but it must be 150x150.
#
# Image size of 7_Stage_8_U2254663.jpg is (405, 329), but it must be 150x150.
#
# 8_10_2162526.HEIC has invalid extension
#
# Image size of 8_10_2254417.jpg is (177, 177), but it must be 150x150.
#
# 8_1_2162526.HEIC has invalid extension
#
# Image size of 8_1_2254417.jpg is (177, 177), but it must be 150x150.
#
# 8_2_2162526.HEIC has invalid extension
#
# Image size of 8_2_2254417.jpg is (177, 177), but it must be 150x150.
#
# 8_3_2162526.HEIC has invalid extension
#
# Image size of 8_3_2254417.jpg is (177, 177), but it must be 150x150.
#
# 8_4_2162526.HEIC has invalid extension
#
# Image size of 8_4_2254417.jpg is (177, 177), but it must be 150x150.
#
# 8_5_2162526.HEIC has invalid extension
#
# Image size of 8_5_2254417.jpg is (177, 177), but it must be 150x150.
#
# 8_6_2162526.HEIC has invalid extension
#
# Image size of 8_6_2254417.jpg is (177, 177), but it must be 150x150.
#
# 8_7_2162526.HEIC has invalid extension
#
# Image size of 8_7_2254417.jpg is (177, 177), but it must be 150x150.
#
# 8_8_2162526.HEIC has invalid extension
#
# Image size of 8_8_2254417.jpg is (177, 177), but it must be 150x150.
#
# 8_9_2162526.HEIC has invalid extension
#
# Image size of 8_9_2254417.jpg is (177, 177), but it must be 150x150.
#
# Image size of 8_Stage_8_U2182091.jpg is (3024, 4032), but it must be 150x150.
#
# Image size of 8_Stage_8_U2254663.jpg is (443, 340), but it must be 150x150.
#
# Image size of 9_Stage_8_U2182091.jpg is (3024, 4032), but it must be 150x150.
#
# Image size of 9_Stage_8_U2254663.jpg is (442, 361), but it must be 150x150.
#
# Image size of Resized S 8-U2187423-1.jpg is (113, 150), but it must be 150x150.
#
# Image size of Resized S 8-U2187423-10.jpg is (113, 150), but it must be 150x150.
#
# Image size of Resized S 8-U2187423-2.jpg is (113, 150), but it must be 150x150.
#
# Image size of Resized S 8-U2187423-3.jpg is (113, 150), but it must be 150x150.
#
# Image size of Resized S 8-U2187423-4.jpg is (113, 150), but it must be 150x150.
#
# Image size of Resized S 8-U2187423-5.jpg is (113, 150), but it must be 150x150.
#
# Image size of Resized S 8-U2187423-6.jpg is (113, 150), but it must be 150x150.
#
# Image size of Resized S 8-U2187423-7.jpg is (113, 150), but it must be 150x150.
#
# Image size of Resized S 8-U2187423-8.jpg is (113, 150), but it must be 150x150.
#
# Image size of Resized S 8-U2187423-9.jpg is (113, 150), but it must be 150x150.
#
# Image size of stage 8 (u2187406).jpg is (3840, 5120), but it must be 150x150.
#
# Image size of STAGE 8 1 U2266514.jpg is (113, 150), but it must be 150x150.
#
# Image size of Stage 8 10 U2266514.jpg is (113, 150), but it must be 150x150.
#
# Image size of Stage 8 2 U2266514.jpg is (113, 150), but it must be 150x150.
#
# Image size of Stage 8 3 U2266514.jpg is (113, 150), but it must be 150x150.
#
# Image size of Stage 8 4 U2266514.jpg is (113, 150), but it must be 150x150.
#
# Image size of Stage 8 5 U2266514.jpg is (113, 150), but it must be 150x150.
#
# Image size of STAGE 8 6 U2266514.jpg is (113, 150), but it must be 150x150.
#
# Image size of Stage 8 7 U2266514.jpg is (113, 150), but it must be 150x150.
#
# Image size of Stage 8 8 U2266514.jpg is (113, 150), but it must be 150x150.
#
# Image size of Stage 8 9 U2266514.jpg is (113, 150), but it must be 150x150.
#
# Image size of Stage 8-2187423-1.jpg is (113, 150), but it must be 150x150.
#
# Image size of Stage 8-2187423-10.jpg is (113, 150), but it must be 150x150.
#
# Image size of Stage 8-2187423-2.jpg is (113, 150), but it must be 150x150.
#
# Image size of Stage 8-2187423-3.jpg is (1200, 1600), but it must be 150x150.
#
# Image size of Stage 8-2187423-4.jpg is (1200, 1600), but it must be 150x150.
#
# Image size of Stage 8-2187423-5.jpg is (113, 150), but it must be 150x150.
#
# Image size of Stage 8-2187423-6.jpg is (113, 150), but it must be 150x150.
#
# Image size of Stage 8-2187423-7.jpg is (1200, 1600), but it must be 150x150.
#
# Image size of Stage 8-2187423-8.jpg is (113, 150), but it must be 150x150.
#
# Image size of Stage 8-2187423-9.jpg is (113, 150), but it must be 150x150.
#
# Image size of Stage8_U2266219(4).jpeg is (200, 150), but it must be 150x150.
#
# Image size of stage8_u2353673 (1) copy.jpg is (750, 750), but it must be 150x150.
#
# Image size of stage8_u2353673 (10) copy.jpg is (750, 750), but it must be 150x150.
#
# Image size of stage8_u2353673 (2) copy.jpg is (750, 750), but it must be 150x150.
#
# Image size of stage8_u2353673 (3) copy.jpg is (750, 750), but it must be 150x150.
#
# Image size of stage8_u2353673 (4) copy.jpg is (750, 750), but it must be 150x150.
#
# Image size of stage8_u2353673 (5) copy.jpg is (750, 750), but it must be 150x150.
#
# Image size of stage8_u2353673 (6) copy.jpg is (750, 750), but it must be 150x150.
#
# Image size of stage8_u2353673 (7) copy.jpg is (750, 750), but it must be 150x150.
#
# Image size of stage8_u2353673 (8) copy.jpg is (750, 750), but it must be 150x150.
#
# Image size of stage8_u2353673 (9) copy.jpg is (750, 750), but it must be 150x150.
#
# Image size of Stage_8.10_u2352832.jpg is (3072, 3072), but it must be 150x150.
#
# Image size of Stage_8.1_u2352832.jpg is (3072, 3072), but it must be 150x150.
#
# Image size of Stage_8.2_u2352832.jpg is (3072, 3072), but it must be 150x150.
#
# Image size of Stage_8.3_u2352832.jpg is (3072, 3072), but it must be 150x150.
#
# Image size of Stage_8.4_u2352832.jpg is (3072, 3072), but it must be 150x150.
#
# Image size of Stage_8.5_u2352832.jpg is (3072, 3072), but it must be 150x150.
#
# Image size of Stage_8.6_u2352832.jpg is (3072, 3072), but it must be 150x150.
#
# Image size of Stage_8.7_u2352832.jpg is (3072, 3072), but it must be 150x150.
#
# Image size of Stage_8.8_u2352832.jpg is (3072, 3072), but it must be 150x150.
#
# Image size of Stage_8.9_u2352832.jpg is (3072, 3071), but it must be 150x150.
#
# Image size of Stage_8_2452781(1).jpg is (1003, 964), but it must be 150x150.
#
# Image size of Stage_8_2452781(10).jpg is (1095, 1201), but it must be 150x150.
#
# Image size of Stage_8_2452781(2).jpg is (951, 1038), but it must be 150x150.
#
# Image size of Stage_8_2452781(3).jpg is (905, 827), but it must be 150x150.
#
# Image size of Stage_8_2452781(4).jpg is (979, 900), but it must be 150x150.
#
# Image size of Stage_8_2452781(5).jpg is (843, 764), but it must be 150x150.
#
# Image size of Stage_8_2452781(6).jpg is (977, 1145), but it must be 150x150.
#
# Image size of Stage_8_2452781(7).jpg is (912, 1101), but it must be 150x150.
#
# Image size of Stage_8_2452781(8).jpg is (1003, 1036), but it must be 150x150.
#
# Image size of Stage_8_2452781(9).jpg is (1011, 1171), but it must be 150x150.
#
# Image size of Stage_8_U2161141_1.jpg is (4252, 4252), but it must be 150x150.
#
# Image size of Stage_8_U2161141_10.jpg is (4252, 4252), but it must be 150x150.
#
# Image size of Stage_8_U2161141_2.jpg is (4252, 4252), but it must be 150x150.
#
# Image size of Stage_8_U2161141_3.jpg is (4252, 4252), but it must be 150x150.
#
# Image size of Stage_8_U2161141_4.jpg is (4252, 4252), but it must be 150x150.
#
# Image size of Stage_8_U2161141_5.jpg is (4252, 4252), but it must be 150x150.
#
# Image size of Stage_8_U2161141_6.jpg is (4252, 4252), but it must be 150x150.
#
# Image size of Stage_8_U2161141_7.jpg is (4252, 4252), but it must be 150x150.
#
# Image size of Stage_8_U2161141_8.jpg is (4252, 4252), but it must be 150x150.
#
# Image size of Stage_8_U2161141_9.jpg is (4252, 4252), but it must be 150x150.
#
# Image size of Stage_8_U2162049(1).jpeg is (3024, 3620), but it must be 150x150.
#
# Image size of Stage_8_U2162049(10).jpeg is (4032, 3024), but it must be 150x150.
#
# Image size of Stage_8_U2162049(2).jpeg is (3024, 4032), but it must be 150x150.
#
# Image size of Stage_8_U2162049(3).jpeg is (2481, 3364), but it must be 150x150.
#
# Image size of Stage_8_U2162049(4).jpeg is (3024, 4032), but it must be 150x150.
#
# Image size of Stage_8_U2162049(5).jpeg is (3024, 4032), but it must be 150x150.
#
# Image size of Stage_8_U2162049(6).jpeg is (3024, 4032), but it must be 150x150.
#
# Image size of Stage_8_U2162049(7).jpeg is (2768, 2287), but it must be 150x150.
#
# Image size of Stage_8_U2162049(8).jpeg is (3024, 4032), but it must be 150x150.
#
# Image size of Stage_8_U2162049(9).jpeg is (3024, 3328), but it must be 150x150.
#
# Image size of Stage_8_u2162252 (10).png is (155, 155), but it must be 150x150.
#
# Image size of Stage_8_u2162252 (2).png is (155, 155), but it must be 150x150.
#
# Image size of Stage_8_u2162252 (3).png is (155, 155), but it must be 150x150.
#
# Image size of Stage_8_u2162252 (4).png is (155, 155), but it must be 150x150.
#
# Image size of Stage_8_u2162252 (5).png is (155, 155), but it must be 150x150.
#
# Image size of Stage_8_u2162252 (6).png is (155, 155), but it must be 150x150.
#
# Image size of Stage_8_u2162252 (7).png is (155, 155), but it must be 150x150.
#
# Image size of Stage_8_u2162252 (8).png is (155, 155), but it must be 150x150.
#
# Image size of Stage_8_u2162252 (9).png is (155, 155), but it must be 150x150.
#
# Image size of Stage_8_u2162252.png is (155, 155), but it must be 150x150.
#
# Image size of Stage_8_U2187085_1.jpg is (300, 300), but it must be 150x150.
#
# Image size of Stage_8_U2187085_10.jpg is (300, 300), but it must be 150x150.
#
# Image size of Stage_8_U2187085_2.jpg is (300, 300), but it must be 150x150.
#
# Image size of Stage_8_U2187085_3.jpg is (300, 300), but it must be 150x150.
#
# Image size of Stage_8_U2187085_4.jpg is (300, 300), but it must be 150x150.
#
# Image size of Stage_8_U2187085_5.jpg is (300, 300), but it must be 150x150.
#
# Image size of Stage_8_U2187085_6.jpg is (300, 300), but it must be 150x150.
#
# Image size of Stage_8_U2187085_7.jpg is (300, 300), but it must be 150x150.
#
# Image size of Stage_8_U2187085_8.jpg is (300, 300), but it must be 150x150.
#
# Image size of Stage_8_U2187085_9.jpg is (300, 300), but it must be 150x150.
#
# Image size of Stage_8_U2261710.jpg (10).jpeg is (1512, 2016), but it must be 150x150.
#
# Image size of Stage_8_U2261710.jpg (2).jpeg is (1512, 2016), but it must be 150x150.
#
# Image size of Stage_8_U2261710.jpg (3).jpeg is (1512, 2016), but it must be 150x150.
#
# Image size of Stage_8_U2261710.jpg (4).jpeg is (1512, 2016), but it must be 150x150.
#
# Image size of Stage_8_U2261710.jpg (5).jpeg is (1512, 2016), but it must be 150x150.
#
# Image size of Stage_8_U2261710.jpg (6).jpeg is (1512, 2016), but it must be 150x150.
#
# Image size of Stage_8_U2261710.jpg (7).jpeg is (1512, 2016), but it must be 150x150.
#
# Image size of Stage_8_U2261710.jpg (8).jpeg is (1512, 2016), but it must be 150x150.
#
# Image size of Stage_8_U2261710.jpg (9).jpeg is (1512, 2016), but it must be 150x150.
#
# Image size of Stage_8_U2261710.jpg.jpeg is (1512, 2016), but it must be 150x150.
#
# Unable to open Image: Stage_8_U2265620(1).jpeg
#
# Unable to open Image: Stage_8_U2265620(10).jpeg
#
# Unable to open Image: Stage_8_U2265620(2).jpeg
#
# Unable to open Image: Stage_8_U2265620(3).jpeg
#
# Unable to open Image: Stage_8_U2265620(4).jpeg
#
# Unable to open Image: Stage_8_U2265620(5).jpeg
#
# Unable to open Image: Stage_8_U2265620(6).jpeg
#
# Unable to open Image: Stage_8_U2265620(7).jpeg
#
# Unable to open Image: Stage_8_U2265620(8).jpeg
#
# Unable to open Image: Stage_8_U2265620(9).jpeg
#
# Image size of Stage_8_u2266898 (5).JPG is (132, 132), but it must be 150x150.
#
# Image size of Stage_8_u2266898 (6).JPG is (133, 132), but it must be 150x150.
#
# Image size of Stage_8_u2292637_001.jpg is (4000, 3000), but it must be 150x150.
#
# Image size of Stage_8_u2292637_002.jpg is (4000, 3000), but it must be 150x150.
#
# Image size of Stage_8_u2292637_003.jpg is (4000, 3000), but it must be 150x150.
#
# Image size of Stage_8_u2292637_004.jpg is (4000, 3000), but it must be 150x150.
#
# Image size of Stage_8_u2292637_005.jpg is (4000, 3000), but it must be 150x150.
#
# Image size of Stage_8_u2292637_006.jpg is (4000, 3000), but it must be 150x150.
#
# Image size of Stage_8_u2292637_007.jpg is (4000, 3000), but it must be 150x150.
#
# Image size of Stage_8_u2292637_008.jpg is (4000, 3000), but it must be 150x150.
#
# Image size of Stage_8_u2292637_009.jpg is (4000, 3000), but it must be 150x150.
#
# Image size of Stage_8_u2292637_010.jpg is (4000, 3000), but it must be 150x150.
#
# Image size of Stage_8_U2351103 .jpeg is (960, 742), but it must be 150x150.
#
# Image size of Stage_9_U2351103 .jpeg is (959, 980), but it must be 150x150.
#
# Image size of Step8_ U2181868(1).jpg is (4000, 3000), but it must be 150x150.
#
# Image size of Step8_ U2181868(10).jpg is (4000, 3000), but it must be 150x150.
#
# Image size of Step8_ U2181868(2).jpg is (4000, 3000), but it must be 150x150.
#
# Image size of Step8_ U2181868(3).jpg is (4000, 3000), but it must be 150x150.
#
# Image size of Step8_ U2181868(4).jpg is (4000, 3000), but it must be 150x150.
#
# Image size of Step8_ U2181868(5).jpg is (4000, 3000), but it must be 150x150.
#
# Image size of Step8_ U2181868(6).jpg is (4000, 3000), but it must be 150x150.
#
# Image size of Step8_ U2181868(7).jpg is (4000, 3000), but it must be 150x150.
#
# Image size of Step8_ U2181868(8).jpg is (4000, 3000), but it must be 150x150.
#
# Image size of Step8_ U2181868(9).jpg is (4000, 3000), but it must be 150x150.

# %% [markdown]
# In CHS2406 Assignment 2 notebook section3, reasons for the method of handling the errors can be found.
#
# The reason for using grayscale on image structure was due to the fact that I would get low memory error when using RGB.

# %% [markdown]
# ## Readily Available Model Training

# %%
train_data = np.array(train_data)  # Convert to a NumPy array

# Convert labels to numeric values using LabelEncoder
label_encoder = LabelEncoder()
train_labels = label_encoder.fit_transform(labels)  

# Initialised XGBoost model
#cross-validation to get prediction probabilities
model = XGBClassifier(tree_method="hist", enable_categorical=True)
# Generate predicted probabilities for each sample (method='predict_proba')
pred_probs = cross_val_predict(model, train_data, train_labels, method='predict_proba', cv=10)

# %% [markdown]
# 1. **Data Conversion:** Converts training data to a NumPy array for compatibility with machine learning models.
#
# 2. **Label Encoding:** Converts categorical labels to numeric values, as required by most machine learning models.
#
# 3. **XGBoost Configuration:**
#    - Uses a histogram-based method (`tree_method="hist"`) for faster tree-building.
#    - Enables direct handling of categorical features with `enable_categorical=True`.
#
# 4. **Cross-Validation and Probability Prediction:**
#    - Cross-validation (`cv=10`) improves model performance estimation.
#    - `predict_proba` provides class probabilities, giving more information about model d evaluation.

# %% [markdown]
# ## Image Masking and File Writing

# %%
####################################################################################################
#Filtering Images
####################################################################################################


# Use Cleanlab's filter function
cl_issue_idx = cleanlab.filter.find_label_issues(train_labels, pred_probs, return_indices_ranked_by='self_confidence')

# Initialise a dictionary to count the number of mislabelled images per stage
mislabelled_count = {f"Stage{i}": 0 for i in range(1, 9)}  # Stages 1-8
for idx in cl_issue_idx:  # Iterate over the indices of mislabelled images
    stage_label = labels[idx]  # Get the stage label (folder name) of the mislabelled image
    mislabelled_count[stage_label] += 1  # Increment the mislabel count for the corresponding stage

# Print the results: Number of label issues identified and the indices of the issues
print(f"Number of potential label issues identified: {len(cl_issue_idx)}")
print(f"Indices of label issues: {cl_issue_idx}")

# Mask to filter out the problematic data points
mask = np.ones(len(train_labels), dtype=bool)  # All data points start marked as True
mask[cl_issue_idx] = False

# Filtering the training data, labels, and image paths using the mask
train_data = train_data[mask]  # Mask applied to filter out mislabelled data from train_data
train_labels = np.array(train_labels)[mask]  # Filter out mislabelled labels
image_paths = np.array(image_paths)[mask]  # Filter out mislabelled image paths


print(f"Filtered train data shape: {train_data.shape}")
print(f"Filtered labels shape: {train_labels.shape}")



####################################################################################################
####################################################################################################
#Error Logging
####################################################################################################
####################################################################################################


# Function to write the counts of images with various issues to a file
def write_stage_counts_to_file(title, counts, filename):
    with open(filename, 'w') as file:
        file.write(title + "\n")  # Write the title of the report
        for stage, count in counts.items():  # Write each stage's count
            file.write(f"{stage}: <{count}>\n")

# Various issue counts (unable to open, invalid size, mislabelled, invalid extension) to separate text files
write_stage_counts_to_file("Images that couldn't be opened:", unable_to_open_count, "unable_to_open.txt")
write_stage_counts_to_file("Images that were not 150x150:", invalid_size_count, "invalid_size.txt")
write_stage_counts_to_file("Images that were mislabelled:", mislabelled_count, "mislabelled.txt")
write_stage_counts_to_file("Images that had invalid extension:", invalid_extension_count, "invalid_extension.txt")


####################################################################################################
####################################################################################################
####################################################################################################
####################################################################################################






####################################################################################################
#Valid Data Storage
####################################################################################################


# Initialised list of selected image paths and labels based on filtered labels
selected_image_paths_and_labels = []

# Unique stages from the filtered labels
unique_stages = set(train_labels) 

for stage in unique_stages:  # Iterate over each unique stage
    # Find the indices of images corresponding to the current stage
    stage_indices = [i for i, label in enumerate(train_labels) if label == stage]

    # Append the image paths and labels of the current stage to the list
    for idx in stage_indices:
        selected_image_paths_and_labels.append((image_paths[idx], train_labels[idx]))

# Write the image paths and their associated labels to a text file
with open("image_paths_and_labels.txt", "w") as file:
    for img_path, label in selected_image_paths_and_labels:
        file.write(f"{img_path},{label}\n")  # Format the data as path,label

print("Selected image paths and labels saved to image_paths_and_labels.txt.")
# Out:
# Number of potential label issues identified: 6654
# Indices of label issues: [1405 4494 1409 ... 9655 2193 2733]
# Filtered train data shape: (4496, 22500)
# Filtered labels shape: (4496,)
# Selected image paths and labels saved to image_paths_and_labels.txt.

# %% [markdown]
# Above all the "mislabelled" images are fitlered out (using cleanlab) and are sotored in a text file to be used in the CHS2406 Assignment 2 notebook. Also, number of errors present in every stage are recorded and stored in seperate text files.
